# %%
import os
print(os.getcwd())
# Out:
# /Users/haifeng/coding/PycharmProjects/Machine-Learning/Class/.ipynb_checkpoints

# %%
import pandas as pd
import numpy as np
df_women = pd.read_csv('women.csv', index_col=0, header=0)
df_women.tail(3)
# Out:
#     height  weight
# 13      70     154
# 14      71     159
# 15      72     164

# %%
df_women.shape
# Out:
# (15, 2)

# %%
df_women.columns
# Out:
# Index(['height', 'weight'], dtype='object')

# %%
df_women.describe()
# Out:
#           height      weight
# count  15.000000   15.000000
# mean   65.000000  136.733333
# std     4.472136   15.498694
# min    58.000000  115.000000
# 25%    61.500000  124.500000
# 50%    65.000000  135.000000
# 75%    68.500000  148.000000
# max    72.000000  164.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df_women["height"], df_women["weight"])
plt.xlabel("height")
plt.show()
